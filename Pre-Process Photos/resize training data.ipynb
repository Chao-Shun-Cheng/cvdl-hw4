# %%
import tensorflow.compat.v2 as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt    
import tensorflow.keras
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Flatten, Activation,Conv2D, MaxPooling2D
import datetime
# import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import TensorBoard
import os
import scipy.misc
from PIL import Image

# %%
# K.clear_session()
datagen = ImageDataGenerator(rescale=1.0/255.0,
                             rotation_range=30,   
                             zoom_range = 0.2,  
                             width_shift_range=0.2,  
                             height_shift_range=0.2,)

# prepare iterators
train_it = datagen.flow_from_directory('dataset_dogs_vs_cats/train/',
    class_mode='binary', batch_size=1, target_size=(220, 220))
# Out:
# Found 18696 images belonging to 2 classes.

# %%
i = 0
for X_batch, y_batch in train_it:
    i += 1
    if i == 1000:
        break
    photo = X_batch[0,:,:,:]
    print(photo.shape)
    if y_batch == 1: #dog
        path = 'dataset_dogs_vs_cats/resize_train/dogs/' + str(i) + '_resize.jpg'
    if y_batch == 0: #cat
        path = 'dataset_dogs_vs_cats/resize_train/cats/' + str(i) + '_resize.jpg'
    scipy.misc.imsave(path, photo)
# Out:
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# C:\Users\mec-lab\Anaconda3\envs\nn_class\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning:     `imsave` is deprecated!
#     `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imwrite`` instead.
#   if sys.path[0] == '':
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# (220, 220, 3)
# ...
